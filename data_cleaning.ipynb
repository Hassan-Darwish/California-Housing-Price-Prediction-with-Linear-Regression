# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
ocean_proxi = pd.Series(df['ocean_proximity'])
df.drop(['ocean_proximity'], axis=1, inplace=True)

# %%
X_mean = np.mean(df, axis=0)
X_std = np.std(df, axis=0)
df_normalized = (df-X_mean)/X_std

# %%
df['ocean_proximity'] = ocean_proxi
df_normalized['ocean_proximity'] = df['ocean_proximity']
del ocean_proxi

df_encoded = pd.get_dummies(df_normalized, columns=['ocean_proximity'], dtype=int)
df_encoded
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -1.327835  1.052548            0.982143    -0.804819       -0.970325
# 1      -1.322844  1.043185           -0.607019     2.045890        1.348276
# 2      -1.332827  1.038503            1.856182    -0.535746       -0.825561
# 3      -1.337818  1.038503            1.856182    -0.624215       -0.718768
# 4      -1.337818  1.038503            1.856182    -0.462404       -0.611974
# ...          ...       ...                 ...          ...             ...
# 20635  -0.758826  1.801647           -0.289187    -0.444985       -0.388895
# 20636  -0.818722  1.806329           -0.845393    -0.888704       -0.920488
# 20637  -0.823713  1.778237           -0.924851    -0.174995       -0.125472
# 20638  -0.873626  1.778237           -0.845393    -0.355600       -0.305834
# 20639  -0.833696  1.750146           -1.004309     0.068408        0.185416
#
# ...

# %%
df_encoded.drop(["longitude", "latitude"], axis=1, inplace=True)

del df_normalized

# %%
df_encoded.columns
# Out:
# Index(['housing_median_age', 'total_rooms', 'total_bedrooms', 'population',
#        'households', 'median_income', 'median_house_value',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
df_encoded["median_income"] = df["median_income"]
df_encoded["income_cat"] = pd.cut(
    df_encoded["median_income"],
    bins=[0., 1.5, 3.0, 4.5, 6., np.inf],
    labels=[1, 2, 3, 4, 5]
    )
df_encoded
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                0.982143    -0.804819       -0.970325   -0.974429
# 1               -0.607019     2.045890        1.348276    0.861439
# 2                1.856182    -0.535746       -0.825561   -0.820777
# 3                1.856182    -0.624215       -0.718768   -0.766028
# 4                1.856182    -0.462404       -0.611974   -0.759847
# ...                   ...          ...             ...         ...
# 20635           -0.289187    -0.444985       -0.388895   -0.512592
# 20636           -0.845393    -0.888704       -0.920488   -0.944405
# 20637           -0.924851    -0.174995       -0.125472   -0.369537
# 20638           -0.845393    -0.355600       -0.305834   -0.604429
# 20639           -1.004309     0.068408        0.185416   -0.033977
#
#        households  median_income  median_house_value  \
# 0       -0.977033         8.3252            2.129631
# ...

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_idx, test_idx in split.split(df_encoded, df_encoded["income_cat"]):
    strat_train_set = df_encoded.loc[train_idx]
    strat_test_set = df_encoded.loc[test_idx]

# %%
for dataset in (strat_train_set, strat_test_set):
    dataset.drop(['income_cat'], axis=1, inplace=True)

# %%
X_mean = np.mean(df['median_income'])
X_std = np.std(df['median_income'])
strat_train_set['median_income'] = strat_test_set['median_income'] = (df['median_income']-X_mean)/X_std

# %%
strat_train_set.to_csv('housing_training.csv')
strat_test_set.to_csv('housing_testing.csv')
